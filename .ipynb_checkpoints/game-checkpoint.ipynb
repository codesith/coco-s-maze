# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from ipywidgets import Layout, HTML
from IPython.core.interactiveshell import InteractiveShell
from ipyevents import Event
import threading

# %%
def loadMaze(n):
    df = pd.read_csv("./mazes/"+str(n)+".txt", header=None)
    maze = df.to_numpy()
    maze[maze == "#"] = "️️🔲"
    maze[maze == "1"] = "️️🐇"
    maze[maze == "2"] = "️️🦩"
    maze[maze == "3"] = "️️🦢"
    maze[maze == "4"] = "️️🦘"
    maze[maze == '5'] = '🏠'
    df = df.style.set_properties(**{'height': '50px', 'width':'50px', 'font-size':'50px', 'font-weight':'heavy',
                               'padding':'0px', 'margin':'0px', 'line-height':'1'})
    return df

# %%
df = loadMaze(1)
df
# Out:
# <style  type="text/css" >
#     #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col0 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col1 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col2 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col3 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col4 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col5 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col6 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col7 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col8 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col9 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col10 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col11 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col12 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col13 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row0_col14 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col0 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col1 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col2 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col3 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col4 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col5 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col6 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col7 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col8 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col9 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col10 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col11 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col12 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col13 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row1_col14 {
#             height:  50px;
#             width:  50px;
#             font-size:  50px;
#             font-weight:  heavy;
#             padding:  0px;
#             margin:  0px;
#             line-height:  1;
#         }    #T_9d062544_fc8c_11ea_87d0_acde48001122row2_col0 {
#             height:  50px;
#             width:  50
